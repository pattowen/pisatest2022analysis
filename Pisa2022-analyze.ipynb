# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline


pd.options.display.max_rows = 9999

# %% [markdown]
# 2022 PISA Dataset

# %%
pisa2022_school_df = pd.read_sas(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\STU_QQQ_SAS\cy08msp_stu_qqq.sas7bdat", encoding='cp1252')
pisa2022_school_df
# Out:
#         CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen STRATUM SUBNATIO  \
# 0       ALB      8.0    800282.0    800001.0  08MS  000800   ALB03  0080000
# 1       ALB      8.0    800115.0    800002.0  08MS  000800   ALB03  0080000
# 2       ALB      8.0    800242.0    800003.0  08MS  000800   ALB01  0080000
# 3       ALB      8.0    800245.0    800005.0  08MS  000800   ALB08  0080000
# 4       ALB      8.0    800285.0    800006.0  08MS  000800   ALB03  0080000
# ...     ...      ...         ...         ...   ...     ...     ...      ...
# 613739  UZB    860.0  86000120.0  86007488.0  08MS  086000   UZB26  8600000
# 613740  UZB    860.0  86000140.0  86007489.0  08MS  086000   UZB04  8600000
# 613741  UZB    860.0  86000024.0  86007490.0  08MS  086000   UZB10  8600000
# 613742  UZB    860.0  86000174.0  86007491.0  08MS  086000   UZB16  8600000
# 613743  UZB    860.0  86000123.0  86007492.0  08MS  086000   UZB10  8600000
#
#          REGION  OECD  ...  PV4MPRE  PV5MPRE  PV6MPRE  PV7MPRE  PV8MPRE  \
# 0         800.0   0.0  ...  203.029  219.817  331.017  223.752  305.671
# 1         800.0   0.0  ...  321.405  320.452  284.836  364.565  304.044
# 2         800.0   0.0  ...  376.019  285.901  289.896  338.469  316.296
# 3         800.0   0.0  ...  303.422  327.793  165.575  246.156  238.322
# 4         800.0   0.0  ...  514.739  539.850  461.793  514.465  510.462
# ...         ...   ...  ...      ...      ...      ...      ...      ...
# 613739  86000.0   0.0  ...  306.551  271.135  386.969  376.271  368.287
# 613740  86000.0   0.0  ...  335.952  232.583  179.328  233.470  203.001
# 613741  86000.0   0.0  ...  451.614  432.586  387.329  456.236  424.790
# 613742  86000.0   0.0  ...  272.346  317.838  248.165  405.860  364.173
# 613743  86000.0   0.0  ...  416.631  337.422  370.817  395.176  412.317
#
#         PV9MPRE  PV10MPRE    SENWT           VER_DAT      i
# 0       230.156   289.436  0.55561  03MAY23:10:11:25  218.0
# 1       347.626   352.269  0.76431  03MAY23:10:11:25  218.0
# 2       324.361   343.351  1.37877  03MAY23:10:11:25  218.0
# 3       275.860   227.466  1.49361  03MAY23:10:11:26  218.0
# 4       490.537   503.793  0.65249  03MAY23:10:11:26  218.0
# ...         ...       ...      ...               ...    ...
# 613739  395.329   278.263  0.71987  02MAY23:13:18:15  218.0
# 613740  254.340   233.187  0.65541  02MAY23:13:18:13  218.0
# 613741  408.986   460.542  0.67910  02MAY23:13:18:13  218.0
# 613742  346.663   341.668  0.68618  02MAY23:13:18:14  218.0
# 613743  390.490   439.211  0.67910  02MAY23:13:18:13  218.0
#
# [613744 rows x 1279 columns]

# %%
##pisa2022_school_df.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# 2022 PISA Score Dataset

# %%
pisa2022_avr_scores_df  = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\data\Average_score.csv", encoding = "ISO-8859-1")
###pisa2022_avr_scores_df

# %% [markdown]
# 2022 PISA Math Scores

# %%
###pisa2022_math_scores_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\data\math_score.csv",encoding = "ISO-8859-1")
###pisa2022_math_scores_df

# %% [markdown]
# 2022 PISA Science Scores

# %%
#pisa2022_sci_scores_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\data\Science_score.csv", encoding = "ISO-8859-1")
###pisa2022_sci_scores_df

# %% [markdown]
# 2022 PISA Reading Scores

# %%
#pisa2022_read_scores_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\data\Reading_score.csv", encoding = "ISO-8859-1")
###pisa2022_read_scores_df

# %%
#pisa2022_sci_scores_df.info()

# %% [markdown]
# ISO alpha-3 code list

# %%
if os.path.exists(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\data\country_codes.csv"):
    os.remove(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\data\country_codes.csv")

file_input = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\raw\country_codes.txt", "r")
file_output = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\data\country_codes.csv", "w")

# Add a header
file_output.write("Code,Country/Region\n")

# Replace the space separator with a comma
for line in file_input:
    new_line = line[:3] + ',' + line[4:]
    file_output.write(new_line)

file_input.close()
file_output.close()

# %%
country_codes_file = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\data\country_codes.csv", "r")

for line in country_codes_file:
    if (line.count(',') > 1):
        print(line)

country_codes_file.close()
# Out:
# BOL,Bolivia, Plurinational State of
#
# COD,Congo, the Democratic Republic of the
#
# FSM,Micronesia, Federated States of
#
# IRN,Iran, Islamic Republic of
#
# KOR,Korea, Republic of
#
# MDA,Moldova, Republic of
#
# MKD,Macedonia, the former Yugoslav Republic of
#
# PRK,Korea, Democratic People's Republic of
#
# PSE,Palestinian Territory, Occupied
#
# SHN,Saint Helena, Ascension and Tristan da Cunha
#
# TAP,Taiwan, Province of China
#
# TZA,Tanzania, United Republic of
#
# VEN,Venezuela, Bolivarian Republic of
#
# VGB,Virgin Islands, British
#
# VIR,Virgin Islands, U.S.

# %%
# Open the file in read mode
country_codes_file = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\data\country_codes.csv", "r")

# Replace all instances of ", " with "-"
country_codes_data = country_codes_file.read()
country_codes_data = country_codes_data.replace(", ", " - ")

country_codes_file.close()

# Open the file again in write mode
country_codes_file = open(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\data\country_codes.csv", "w")
country_codes_file.write(country_codes_data)
country_codes_file.close()

# %% [markdown]
# CONSTRUCTED ISO 3166-1 ALPHA-3 CODE LIST

# %%
country_codes_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400_Project_Development\CN1-2023\PisaTest2022-analysis\StreamlitDev\data_file\data\country_codes.csv")

# %%
country_codes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Code            246 non-null    object
#  1   Country/Region  246 non-null    object
# dtypes: object(2)
# memory usage: 4.0+ KB

# %% [markdown]
# DATA PREPROCESSING
#
# Merging the 2022 PISA School Dataset and ISO  alpha-3 Code List

# %%
pisa2022_df = pisa2022_school_df.merge(country_codes_df, left_on = "CNT", right_on = "Code", how = 'left')
pisa2022_df
# Out:
#         CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen STRATUM SUBNATIO  \
# 0       ALB      8.0    800282.0    800001.0  08MS  000800   ALB03  0080000
# 1       ALB      8.0    800115.0    800002.0  08MS  000800   ALB03  0080000
# 2       ALB      8.0    800242.0    800003.0  08MS  000800   ALB01  0080000
# 3       ALB      8.0    800245.0    800005.0  08MS  000800   ALB08  0080000
# 4       ALB      8.0    800285.0    800006.0  08MS  000800   ALB03  0080000
# ...     ...      ...         ...         ...   ...     ...     ...      ...
# 613739  UZB    860.0  86000120.0  86007488.0  08MS  086000   UZB26  8600000
# 613740  UZB    860.0  86000140.0  86007489.0  08MS  086000   UZB04  8600000
# 613741  UZB    860.0  86000024.0  86007490.0  08MS  086000   UZB10  8600000
# 613742  UZB    860.0  86000174.0  86007491.0  08MS  086000   UZB16  8600000
# 613743  UZB    860.0  86000123.0  86007492.0  08MS  086000   UZB10  8600000
#
#          REGION  OECD  ...  PV6MPRE  PV7MPRE  PV8MPRE  PV9MPRE  PV10MPRE  \
# 0         800.0   0.0  ...  331.017  223.752  305.671  230.156   289.436
# 1         800.0   0.0  ...  284.836  364.565  304.044  347.626   352.269
# 2         800.0   0.0  ...  289.896  338.469  316.296  324.361   343.351
# 3         800.0   0.0  ...  165.575  246.156  238.322  275.860   227.466
# 4         800.0   0.0  ...  461.793  514.465  510.462  490.537   503.793
# ...         ...   ...  ...      ...      ...      ...      ...       ...
# 613739  86000.0   0.0  ...  386.969  376.271  368.287  395.329   278.263
# 613740  86000.0   0.0  ...  179.328  233.470  203.001  254.340   233.187
# 613741  86000.0   0.0  ...  387.329  456.236  424.790  408.986   460.542
# 613742  86000.0   0.0  ...  248.165  405.860  364.173  346.663   341.668
# 613743  86000.0   0.0  ...  370.817  395.176  412.317  390.490   439.211
#
#           SENWT           VER_DAT      i  Code  Country/Region
# 0       0.55561  03MAY23:10:11:25  218.0   ALB         Albania
# 1       0.76431  03MAY23:10:11:25  218.0   ALB         Albania
# 2       1.37877  03MAY23:10:11:25  218.0   ALB         Albania
# 3       1.49361  03MAY23:10:11:26  218.0   ALB         Albania
# 4       0.65249  03MAY23:10:11:26  218.0   ALB         Albania
# ...         ...               ...    ...   ...             ...
# 613739  0.71987  02MAY23:13:18:15  218.0   UZB      Uzbekistan
# 613740  0.65541  02MAY23:13:18:13  218.0   UZB      Uzbekistan
# 613741  0.67910  02MAY23:13:18:13  218.0   UZB      Uzbekistan
# 613742  0.68618  02MAY23:13:18:14  218.0   UZB      Uzbekistan
# 613743  0.67910  02MAY23:13:18:13  218.0   UZB      Uzbekistan
#
# [613744 rows x 1281 columns]

# %% [markdown]
# Check for null values in 'Country/Region'

# %%
pisa2022_df[pisa2022_df['Country/Region'].isnull()]['CNT'].unique()
# Out:
# array(['QAZ', 'KSV', 'QUR'], dtype=object)

# %%
addl_codes = {"QAZ": "Azerbaijan",
              "TAP": "Taiwan",
              "KSV": "Kosovo",
              "QUR": "Ukraine"}

# %%
for code, country in addl_codes.items():
    pisa2022_df.loc[pisa2022_df['CNT'] == code, 'Country/Region'] = country
    
pisa2022_df
# Out:
#         CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen STRATUM SUBNATIO  \
# 0       ALB      8.0    800282.0    800001.0  08MS  000800   ALB03  0080000
# 1       ALB      8.0    800115.0    800002.0  08MS  000800   ALB03  0080000
# 2       ALB      8.0    800242.0    800003.0  08MS  000800   ALB01  0080000
# 3       ALB      8.0    800245.0    800005.0  08MS  000800   ALB08  0080000
# 4       ALB      8.0    800285.0    800006.0  08MS  000800   ALB03  0080000
# ...     ...      ...         ...         ...   ...     ...     ...      ...
# 613739  UZB    860.0  86000120.0  86007488.0  08MS  086000   UZB26  8600000
# 613740  UZB    860.0  86000140.0  86007489.0  08MS  086000   UZB04  8600000
# 613741  UZB    860.0  86000024.0  86007490.0  08MS  086000   UZB10  8600000
# 613742  UZB    860.0  86000174.0  86007491.0  08MS  086000   UZB16  8600000
# 613743  UZB    860.0  86000123.0  86007492.0  08MS  086000   UZB10  8600000
#
#          REGION  OECD  ...  PV6MPRE  PV7MPRE  PV8MPRE  PV9MPRE  PV10MPRE  \
# 0         800.0   0.0  ...  331.017  223.752  305.671  230.156   289.436
# 1         800.0   0.0  ...  284.836  364.565  304.044  347.626   352.269
# 2         800.0   0.0  ...  289.896  338.469  316.296  324.361   343.351
# 3         800.0   0.0  ...  165.575  246.156  238.322  275.860   227.466
# 4         800.0   0.0  ...  461.793  514.465  510.462  490.537   503.793
# ...         ...   ...  ...      ...      ...      ...      ...       ...
# 613739  86000.0   0.0  ...  386.969  376.271  368.287  395.329   278.263
# 613740  86000.0   0.0  ...  179.328  233.470  203.001  254.340   233.187
# 613741  86000.0   0.0  ...  387.329  456.236  424.790  408.986   460.542
# 613742  86000.0   0.0  ...  248.165  405.860  364.173  346.663   341.668
# 613743  86000.0   0.0  ...  370.817  395.176  412.317  390.490   439.211
#
#           SENWT           VER_DAT      i  Code  Country/Region
# 0       0.55561  03MAY23:10:11:25  218.0   ALB         Albania
# 1       0.76431  03MAY23:10:11:25  218.0   ALB         Albania
# 2       1.37877  03MAY23:10:11:25  218.0   ALB         Albania
# 3       1.49361  03MAY23:10:11:26  218.0   ALB         Albania
# 4       0.65249  03MAY23:10:11:26  218.0   ALB         Albania
# ...         ...               ...    ...   ...             ...
# 613739  0.71987  02MAY23:13:18:15  218.0   UZB      Uzbekistan
# 613740  0.65541  02MAY23:13:18:13  218.0   UZB      Uzbekistan
# 613741  0.67910  02MAY23:13:18:13  218.0   UZB      Uzbekistan
# 613742  0.68618  02MAY23:13:18:14  218.0   UZB      Uzbekistan
# 613743  0.67910  02MAY23:13:18:13  218.0   UZB      Uzbekistan
#
# [613744 rows x 1281 columns]

# %%
pisa2022_df['Country/Region'].isnull().values.any()
# Out:
# False

# %% [markdown]
# 2. Merging the 2022 PISA School Dataset, ISO  alpha-3 Code List, and 2022 PISA Scores Dataset

# %%
pisa_school_only = set(pisa2022_df['Country/Region']) - set(pisa2022_avr_scores_df['Country/Region'])
pisa_school_only
# Out:
# {'Hong Kong',
#  'Korea - Republic of',
#  'Macao',
#  'Macedonia - the former Yugoslav Republic of',
#  'Moldova - Republic of',
#  'Palestinian Territory - Occupied',
#  'Slovakia'}

# %%
pisa_school_only_tokens = {}
excluded = ['of', 'the', '-', 'former', 'Federation', 'Republic', 'Occupied', 'Yugoslav' ]

for region in pisa_school_only:
    # Remove punctuation marks
    region_clean = region.replace('(', '')
    region_clean = region_clean.replace(')', '')
    region_clean = region_clean.replace(',', '')
    region_clean = region_clean.replace(',', '')
    
    pisa_school_only_tokens[region] = set()
    
    # Tokenize the country/region name into constituent words
    for token in region_clean.split():
        if token not in excluded:
            pisa_school_only_tokens[region].add(token)
            
pisa_school_only_tokens
# Out:
# {'Macao': {'Macao'},
#  'Macedonia - the former Yugoslav Republic of': {'Macedonia'},
#  'Hong Kong': {'Hong', 'Kong'},
#  'Slovakia': {'Slovakia'},
#  'Moldova - Republic of': {'Moldova'},
#  'Palestinian Territory - Occupied': {'Palestinian', 'Territory'},
#  'Korea - Republic of': {'Korea'}}

# %%
pisa_school_only_tokens['Slovakia'].add('Slovak Republic')


pisa_school_only_tokens
# Out:
# {'Macao': {'Macao'},
#  'Macedonia - the former Yugoslav Republic of': {'Macedonia'},
#  'Hong Kong': {'Hong', 'Kong'},
#  'Slovakia': {'Slovak Republic', 'Slovakia'},
#  'Moldova - Republic of': {'Moldova'},
#  'Palestinian Territory - Occupied': {'Palestinian', 'Territory'},
#  'Korea - Republic of': {'Korea'}}

# %%
pisa2022_avr_scores_only = set(pisa2022_avr_scores_df['Country/Region']) - set(pisa2022_df['Country/Region'])
candidates = {}

for pisa_school_region, tokens in pisa_school_only_tokens.items():
    for token in tokens:
        for pisa_scores_region in pisa2022_avr_scores_only:
            if token in pisa_scores_region:
                candidates[pisa_school_region] = pisa_scores_region
            
candidates
# Out:
# {'Macao': 'Macao (China)',
#  'Macedonia - the former Yugoslav Republic of': 'North Macedonia',
#  'Hong Kong': 'Hong Kong (China)',
#  'Slovakia': 'Slovak Republic',
#  'Moldova - Republic of': 'Moldova',
#  'Palestinian Territory - Occupied': 'Palestinian Authority',
#  'Korea - Republic of': 'Korea'}

# %%
pisa_scores_only = set(pisa2022_avr_scores_df['Country/Region']) - set(pisa2022_df['Country/Region'])
candidates = {}

for pisa_school_region, tokens in pisa_school_only_tokens.items():
    for token in tokens:
        for pisa_scores_region in pisa_scores_only:
            if token in pisa_scores_region:
                candidates[pisa_school_region] = pisa_scores_region
            
candidates
# Out:
# {'Macao': 'Macao (China)',
#  'Macedonia - the former Yugoslav Republic of': 'North Macedonia',
#  'Hong Kong': 'Hong Kong (China)',
#  'Slovakia': 'Slovak Republic',
#  'Moldova - Republic of': 'Moldova',
#  'Palestinian Territory - Occupied': 'Palestinian Authority',
#  'Korea - Republic of': 'Korea'}

# %%
for pisa_school_region, pisa_scores_region in candidates.items():
    pisa2022_df.loc[pisa2022_df['Country/Region'] == pisa_school_region, 'Country/Region'] = pisa_scores_region
    
pisa2022_df
# Out:
#         CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen STRATUM SUBNATIO  \
# 0       ALB      8.0    800282.0    800001.0  08MS  000800   ALB03  0080000
# 1       ALB      8.0    800115.0    800002.0  08MS  000800   ALB03  0080000
# 2       ALB      8.0    800242.0    800003.0  08MS  000800   ALB01  0080000
# 3       ALB      8.0    800245.0    800005.0  08MS  000800   ALB08  0080000
# 4       ALB      8.0    800285.0    800006.0  08MS  000800   ALB03  0080000
# ...     ...      ...         ...         ...   ...     ...     ...      ...
# 613739  UZB    860.0  86000120.0  86007488.0  08MS  086000   UZB26  8600000
# 613740  UZB    860.0  86000140.0  86007489.0  08MS  086000   UZB04  8600000
# 613741  UZB    860.0  86000024.0  86007490.0  08MS  086000   UZB10  8600000
# 613742  UZB    860.0  86000174.0  86007491.0  08MS  086000   UZB16  8600000
# 613743  UZB    860.0  86000123.0  86007492.0  08MS  086000   UZB10  8600000
#
#          REGION  OECD  ...  PV6MPRE  PV7MPRE  PV8MPRE  PV9MPRE  PV10MPRE  \
# 0         800.0   0.0  ...  331.017  223.752  305.671  230.156   289.436
# 1         800.0   0.0  ...  284.836  364.565  304.044  347.626   352.269
# 2         800.0   0.0  ...  289.896  338.469  316.296  324.361   343.351
# 3         800.0   0.0  ...  165.575  246.156  238.322  275.860   227.466
# 4         800.0   0.0  ...  461.793  514.465  510.462  490.537   503.793
# ...         ...   ...  ...      ...      ...      ...      ...       ...
# 613739  86000.0   0.0  ...  386.969  376.271  368.287  395.329   278.263
# 613740  86000.0   0.0  ...  179.328  233.470  203.001  254.340   233.187
# 613741  86000.0   0.0  ...  387.329  456.236  424.790  408.986   460.542
# 613742  86000.0   0.0  ...  248.165  405.860  364.173  346.663   341.668
# 613743  86000.0   0.0  ...  370.817  395.176  412.317  390.490   439.211
#
#           SENWT           VER_DAT      i  Code  Country/Region
# 0       0.55561  03MAY23:10:11:25  218.0   ALB         Albania
# 1       0.76431  03MAY23:10:11:25  218.0   ALB         Albania
# 2       1.37877  03MAY23:10:11:25  218.0   ALB         Albania
# 3       1.49361  03MAY23:10:11:26  218.0   ALB         Albania
# 4       0.65249  03MAY23:10:11:26  218.0   ALB         Albania
# ...         ...               ...    ...   ...             ...
# 613739  0.71987  02MAY23:13:18:15  218.0   UZB      Uzbekistan
# 613740  0.65541  02MAY23:13:18:13  218.0   UZB      Uzbekistan
# 613741  0.67910  02MAY23:13:18:13  218.0   UZB      Uzbekistan
# 613742  0.68618  02MAY23:13:18:14  218.0   UZB      Uzbekistan
# 613743  0.67910  02MAY23:13:18:13  218.0   UZB      Uzbekistan
#
# [613744 rows x 1281 columns]

# %%
df_pisa2022 = pisa2022_df.merge(pisa2022_avr_scores_df, left_on = 'Country/Region', right_on = 'Country/Region', how = 'left')

df_pisa2022
# Out:
#         CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen STRATUM SUBNATIO  \
# 0       ALB      8.0    800282.0    800001.0  08MS  000800   ALB03  0080000
# 1       ALB      8.0    800115.0    800002.0  08MS  000800   ALB03  0080000
# 2       ALB      8.0    800242.0    800003.0  08MS  000800   ALB01  0080000
# 3       ALB      8.0    800245.0    800005.0  08MS  000800   ALB08  0080000
# 4       ALB      8.0    800285.0    800006.0  08MS  000800   ALB03  0080000
# ...     ...      ...         ...         ...   ...     ...     ...      ...
# 613739  UZB    860.0  86000120.0  86007488.0  08MS  086000   UZB26  8600000
# 613740  UZB    860.0  86000140.0  86007489.0  08MS  086000   UZB04  8600000
# 613741  UZB    860.0  86000024.0  86007490.0  08MS  086000   UZB10  8600000
# 613742  UZB    860.0  86000174.0  86007491.0  08MS  086000   UZB16  8600000
# 613743  UZB    860.0  86000123.0  86007492.0  08MS  086000   UZB10  8600000
#
#          REGION  OECD  ...  PV8MPRE  PV9MPRE  PV10MPRE    SENWT  \
# 0         800.0   0.0  ...  305.671  230.156   289.436  0.55561
# 1         800.0   0.0  ...  304.044  347.626   352.269  0.76431
# 2         800.0   0.0  ...  316.296  324.361   343.351  1.37877
# 3         800.0   0.0  ...  238.322  275.860   227.466  1.49361
# 4         800.0   0.0  ...  510.462  490.537   503.793  0.65249
# ...         ...   ...  ...      ...      ...       ...      ...
# 613739  86000.0   0.0  ...  368.287  395.329   278.263  0.71987
# 613740  86000.0   0.0  ...  203.001  254.340   233.187  0.65541
# 613741  86000.0   0.0  ...  424.790  408.986   460.542  0.67910
# 613742  86000.0   0.0  ...  364.173  346.663   341.668  0.68618
# 613743  86000.0   0.0  ...  412.317  390.490   439.211  0.67910
#
#                  VER_DAT      i  Code  Country/Region  Rank  Average_Score
# 0       03MAY23:10:11:25  218.0   ALB         Albania    70          367.3
# 1       03MAY23:10:11:25  218.0   ALB         Albania    70          367.3
# 2       03MAY23:10:11:25  218.0   ALB         Albania    70          367.3
# 3       03MAY23:10:11:26  218.0   ALB         Albania    70          367.3
# 4       03MAY23:10:11:26  218.0   ALB         Albania    70          367.3
# ...                  ...    ...   ...             ...   ...            ...
# 613739  02MAY23:13:18:15  218.0   UZB      Uzbekistan    78          351.7
# 613740  02MAY23:13:18:13  218.0   UZB      Uzbekistan    78          351.7
# 613741  02MAY23:13:18:13  218.0   UZB      Uzbekistan    78          351.7
# 613742  02MAY23:13:18:14  218.0   UZB      Uzbekistan    78          351.7
# 613743  02MAY23:13:18:13  218.0   UZB      Uzbekistan    78          351.7
#
# [613744 rows x 1283 columns]

# %% [markdown]
# Math Literacy

# %%
df_pisa2022[['PV1MATH','PV2MATH','PV3MATH', 'PV4MATH', 'PV5MATH','PV6MATH','PV7MATH','PV8MATH', 'PV9MATH', 'PV10MATH']].describe()
df_pisa2022['Avg_Math_Literacy'] = df_pisa2022[['PV1MATH','PV2MATH','PV3MATH', 'PV4MATH', 'PV5MATH','PV6MATH','PV7MATH','PV8MATH', 'PV9MATH', 'PV10MATH']].mean(axis=1)

# %%
df_pisa2022[['PV1SCIE','PV2SCIE','PV3SCIE','PV4SCIE','PV5SCIE','PV6SCIE','PV7SCIE','PV8SCIE','PV9SCIE','PV10SCIE']].describe()
df_pisa2022['Avg_Scientific_Literacy'] = df_pisa2022[['PV1SCIE','PV2SCIE','PV3SCIE','PV4SCIE','PV5SCIE','PV6SCIE','PV7SCIE','PV8SCIE','PV9SCIE','PV10SCIE']].mean(axis=1)

# %%
df_pisa2022[['PV1READ','PV2READ','PV3READ', 'PV4READ', 'PV5READ','PV6READ','PV7READ','PV8READ', 'PV9READ', 'PV10READ']].describe()
df_pisa2022['Avg_Reading_Literacy'] = df_pisa2022[['PV1READ','PV2READ','PV3READ', 'PV4READ', 'PV5READ','PV6READ','PV7READ','PV8READ', 'PV9READ', 'PV10READ']].mean(axis=1)

# %%
df_pisa2022['Overall_Literacy'] = df_pisa2022[['Avg_Math_Literacy','Avg_Scientific_Literacy','Avg_Reading_Literacy']].mean(axis=1)
df_pisa2022[['Avg_Math_Literacy','Avg_Scientific_Literacy','Avg_Reading_Literacy','Overall_Literacy']];

# %%
pisa_analysis_df = df_pisa2022[['CNTSCHID','CNTSTUID', 'Country/Region', 'OECD', 'ST001D01T','ST004D01T','ST250Q04JA','ST250Q05JA','ST307Q10JA','ST034Q06TA','ST294Q02JA','HISCED','Avg_Math_Literacy','Avg_Scientific_Literacy','Avg_Reading_Literacy','Overall_Literacy', 'Average_Score']]
pisa_analysis_df
# Out:
#           CNTSCHID    CNTSTUID Country/Region  OECD  ST001D01T  ST004D01T  \
# 0         800282.0    800001.0        Albania   0.0       10.0        1.0
# 1         800115.0    800002.0        Albania   0.0        9.0        2.0
# 2         800242.0    800003.0        Albania   0.0        9.0        2.0
# 3         800245.0    800005.0        Albania   0.0        8.0        1.0
# 4         800285.0    800006.0        Albania   0.0       10.0        1.0
# ...            ...         ...            ...   ...        ...        ...
# 613739  86000120.0  86007488.0     Uzbekistan   0.0        9.0        1.0
# 613740  86000140.0  86007489.0     Uzbekistan   0.0        9.0        2.0
# 613741  86000024.0  86007490.0     Uzbekistan   0.0       10.0        2.0
# 613742  86000174.0  86007491.0     Uzbekistan   0.0        9.0        1.0
# 613743  86000123.0  86007492.0     Uzbekistan   0.0        9.0        1.0
#
#         ST250Q04JA  ST250Q05JA  ST307Q10JA  ST034Q06TA  ST294Q02JA  HISCED  \
# 0              NaN         NaN         NaN         NaN         6.0     7.0
# 1              1.0         2.0         NaN         4.0         NaN     3.0
# 2              1.0         1.0         NaN         NaN         1.0     5.0
# 3              1.0         1.0         NaN         4.0         6.0     2.0
# 4              1.0         1.0         1.0         4.0         6.0     5.0
# ...            ...         ...         ...         ...         ...     ...
# 613739         1.0         1.0         NaN         NaN         6.0     1.0
# 613740         1.0         2.0         NaN         NaN         3.0    10.0
# 613741         2.0         2.0         NaN         3.0         6.0     3.0
# 613742         2.0         1.0         1.0         4.0         6.0     5.0
# 613743         2.0         1.0         1.0         4.0         6.0     8.0
#
#         Avg_Math_Literacy  Avg_Scientific_Literacy  Avg_Reading_Literacy  \
# 0                223.0351                 301.2603              249.8026
# 1                308.4938                 303.5314              288.8999
# 2                313.7353                 323.6492              311.7785
# 3                298.7323                 210.1502              300.7753
# 4                475.7512                 466.7572              486.6689
# ...                   ...                      ...                   ...
# 613739           327.0151                 288.5284              312.5706
# 613740           286.4383                 282.6895              271.9545
# 613741           411.8666                 380.6084              330.4373
# 613742           338.1192                 372.8060              353.0499
# 613743           390.4744                 387.9732              383.3452
#
#         Overall_Literacy  Average_Score
# 0             258.032667          367.3
# 1             300.308367          367.3
# 2             316.387667          367.3
# 3             269.885933          367.3
# 4             476.392433          367.3
# ...                  ...            ...
# 613739        309.371367          351.7
# 613740        280.360767          351.7
# 613741        374.304100          351.7
# 613742        354.658367          351.7
# 613743        387.264267          351.7
#
# [613744 rows x 17 columns]

# %%
pisa_analysis_df.rename(columns = {'CNTSCHID':'School_ID',
                          'CNTSTUID':'Student_ID',
                          'ST001D01T' : 'Student_Grade',
                          'ST004D01T' : 'Gender',
                          'ST250Q04JA' : 'Smartphone_with_internet',
                          'ST250Q05JA' : 'Internet_access',
                          'ST307Q10JA' : 'Perseverance_Give_up_easily',
                          'ST034Q06TA' : 'Feel_lonely_at_school',  
                          'ST294Q02JA' : 'Study_for_school_or_homework',
                          'HISCED'  : 'Highest_educational_level_parents'
                          }, inplace = True)
pisa_analysis_df
# Out:
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\3875807933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pisa_analysis_df.rename(columns = {'CNTSCHID':'School_ID',
#          School_ID  Student_ID Country/Region  OECD  Student_Grade  Gender  \
# 0         800282.0    800001.0        Albania   0.0           10.0     1.0
# 1         800115.0    800002.0        Albania   0.0            9.0     2.0
# 2         800242.0    800003.0        Albania   0.0            9.0     2.0
# 3         800245.0    800005.0        Albania   0.0            8.0     1.0
# 4         800285.0    800006.0        Albania   0.0           10.0     1.0
# ...            ...         ...            ...   ...            ...     ...
# 613739  86000120.0  86007488.0     Uzbekistan   0.0            9.0     1.0
# 613740  86000140.0  86007489.0     Uzbekistan   0.0            9.0     2.0
# 613741  86000024.0  86007490.0     Uzbekistan   0.0           10.0     2.0
# 613742  86000174.0  86007491.0     Uzbekistan   0.0            9.0     1.0
# 613743  86000123.0  86007492.0     Uzbekistan   0.0            9.0     1.0
#
#         Smartphone_with_internet  Internet_access  \
# 0                            NaN              NaN
# 1                            1.0              2.0
# 2                            1.0              1.0
# 3                            1.0              1.0
# 4                            1.0              1.0
# ...                          ...              ...
# 613739                       1.0              1.0
# 613740                       1.0              2.0
# 613741                       2.0              2.0
# 613742                       2.0              1.0
# 613743                       2.0              1.0
#
#         Perseverance_Give_up_easily  Feel_lonely_at_school  \
# 0                               NaN                    NaN
# 1                               NaN                    4.0
# 2                               NaN                    NaN
# 3                               NaN                    4.0
# 4                               1.0                    4.0
# ...                             ...                    ...
# 613739                          NaN                    NaN
# 613740                          NaN                    NaN
# 613741                          NaN                    3.0
# 613742                          1.0                    4.0
# 613743                          1.0                    4.0
#
#         Study_for_school_or_homework  Highest_educational_level_parents  \
# 0                                6.0                                7.0
# 1                                NaN                                3.0
# 2                                1.0                                5.0
# 3                                6.0                                2.0
# 4                                6.0                                5.0
# ...                              ...                                ...
# 613739                           6.0                                1.0
# 613740                           3.0                               10.0
# 613741                           6.0                                3.0
# 613742                           6.0                                5.0
# 613743                           6.0                                8.0
#
#         Avg_Math_Literacy  Avg_Scientific_Literacy  Avg_Reading_Literacy  \
# 0                223.0351                 301.2603              249.8026
# 1                308.4938                 303.5314              288.8999
# 2                313.7353                 323.6492              311.7785
# 3                298.7323                 210.1502              300.7753
# 4                475.7512                 466.7572              486.6689
# ...                   ...                      ...                   ...
# 613739           327.0151                 288.5284              312.5706
# 613740           286.4383                 282.6895              271.9545
# 613741           411.8666                 380.6084              330.4373
# 613742           338.1192                 372.8060              353.0499
# 613743           390.4744                 387.9732              383.3452
#
#         Overall_Literacy  Average_Score
# 0             258.032667          367.3
# 1             300.308367          367.3
# 2             316.387667          367.3
# 3             269.885933          367.3
# 4             476.392433          367.3
# ...                  ...            ...
# 613739        309.371367          351.7
# 613740        280.360767          351.7
# 613741        374.304100          351.7
# 613742        354.658367          351.7
# 613743        387.264267          351.7
#
# [613744 rows x 17 columns]

# %%
pisa_analysis_df.isnull().sum().sort_values(ascending=False)/613744*100;

# %%
pisa_analysis_df.isnull().sum().sort_values(ascending=False);

# %%
pisa_analysis_df['Study_for_school_or_homework'].unique()
# Out:
# array([ 6., nan,  1.,  3.,  2.,  5.,  4.])

# %%
pisa_analysis_df['OECD'].replace({0: 'NON-OECD', 1: 'OECD'}, inplace=True)
pisa_analysis_df['Gender'].replace({1: 'Female', 2: 'Male'}, inplace=True)
pisa_analysis_df['Smartphone_with_internet'].replace({1: 'Yes', 2: 'No'}, inplace=True)
pisa_analysis_df['Internet_access'].replace({1: 'Yes', 2: 'No'}, inplace=True)
pisa_analysis_df['Perseverance_Give_up_easily'].replace({'Strongly disagree': 'Strongly Disagree', 2: 'Disagree', 3: 'Neither agree nor disagree', 4: 'Agree', 5: 'Strongly Agree'}, inplace=True)
pisa_analysis_df['Feel_lonely_at_school'].replace({1: 'Strongly Agree', 2: 'Agree', 3: 'Disagree', 'Strongly disagreeree': 'Strongly Disagree'}, inplace=True)
pisa_analysis_df['Study_for_school_or_homework'].replace({1: '0 days', 2: '1 days', 3: '2 days', 4: '3 days', 5: '4 days', 6: '5 or more days'}, inplace=True)
# Out:
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\1499373540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pisa_analysis_df['OECD'].replace({0: 'NON-OECD', 1: 'OECD'}, inplace=True)
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\1499373540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pisa_analysis_df['Gender'].replace({1: 'Female', 2: 'Male'}, inplace=True)
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\1499373540.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pisa_analysis_df['Smartphone_with_internet'].replace({1: 'Yes', 2: 'No'}, inplace=True)
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\1499373540.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pisa_analysis_df['Internet_access'].replace({1: 'Yes', 2: 'No'}, inplace=True)
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\1499373540.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pisa_analysis_df['Perseverance_Give_up_easily'].replace({'Strongly disagree': 'Strongly Disagree', 2: 'Disagree', 3: 'Neither agree nor disagree', 4: 'Agree', 5: 'Strongly Agree'}, inplace=True)
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\1499373540.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pisa_analysis_df['Feel_lonely_at_school'].replace({1: 'Strongly Agree', 2: 'Agree', 3: 'Disagree', 'Strongly disagreeree': 'Strongly Disagree'}, inplace=True)
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\1499373540.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pisa_analysis_df['Study_for_school_or_homework'].replace({1: '0 days', 2: '1 days', 3: '2 days', 4: '3 days', 5: '4 days', 6: '5 or more days'}, inplace=True)

# %%
df_pisa2022_final = pisa_analysis_df.dropna()
df_pisa2022_final.shape
# Out:
# (203378, 17)

# %%
print('The cleaned dataframe is composed of only',(203378)/613744 *100,'% of the original dataset.')
# Out:
# The cleaned dataframe is composed of only 33.13726895904481 % of the original dataset.

# %%
df_pisa2022_final
# Out:
#          School_ID  Student_ID Country/Region      OECD  Student_Grade  \
# 4         800285.0    800006.0        Albania  NON-OECD           10.0
# 7         800274.0    800009.0        Albania  NON-OECD            9.0
# 8         800057.0    800010.0        Albania  NON-OECD           10.0
# 15        800039.0    800019.0        Albania  NON-OECD           10.0
# 16        800265.0    800020.0        Albania  NON-OECD           10.0
# ...            ...         ...            ...       ...            ...
# 613730  86000141.0  86007479.0     Uzbekistan  NON-OECD            9.0
# 613731  86000054.0  86007480.0     Uzbekistan  NON-OECD            9.0
# 613733  86000162.0  86007482.0     Uzbekistan  NON-OECD            9.0
# 613742  86000174.0  86007491.0     Uzbekistan  NON-OECD            9.0
# 613743  86000123.0  86007492.0     Uzbekistan  NON-OECD            9.0
#
#         Gender Smartphone_with_internet Internet_access  \
# 4       Female                      Yes             Yes
# 7       Female                      Yes             Yes
# 8       Female                      Yes             Yes
# 15      Female                      Yes             Yes
# 16        Male                      Yes             Yes
# ...        ...                      ...             ...
# 613730    Male                      Yes             Yes
# 613731  Female                       No              No
# 613733    Male                      Yes              No
# 613742  Female                       No             Yes
# 613743  Female                       No             Yes
#
#        Perseverance_Give_up_easily Feel_lonely_at_school  \
# 4                Strongly Disagree     Strongly Disagree
# 7                Strongly Disagree              Disagree
# 8                            Agree     Strongly Disagree
# 15                           Agree     Strongly Disagree
# 16                           Agree     Strongly Disagree
# ...                            ...                   ...
# 613730                       Agree              Disagree
# 613731           Strongly Disagree     Strongly Disagree
# 613733                    Disagree              Disagree
# 613742           Strongly Disagree     Strongly Disagree
# 613743           Strongly Disagree     Strongly Disagree
#
#        Study_for_school_or_homework  Highest_educational_level_parents  \
# 4                    5 or more days                                5.0
# 7                    5 or more days                                4.0
# 8                    5 or more days                                5.0
# 15                   5 or more days                                3.0
# 16                           0 days                               10.0
# ...                             ...                                ...
# 613730               5 or more days                               10.0
# 613731               5 or more days                               10.0
# 613733                       3 days                               10.0
# 613742               5 or more days                                5.0
# 613743               5 or more days                                8.0
#
#         Avg_Math_Literacy  Avg_Scientific_Literacy  Avg_Reading_Literacy  \
# 4                475.7512                 466.7572              486.6689
# 7                258.2991                 332.0824              308.5037
# 8                341.1660                 370.0935              386.9925
# 15               261.5057                 314.8442              319.1974
# 16               362.0900                 356.6150              340.6386
# ...                   ...                      ...                   ...
# 613730           493.3008                 484.1925              415.8632
# 613731           333.6677                 320.7439              301.2888
# 613733           415.4830                 384.9657              414.7816
# 613742           338.1192                 372.8060              353.0499
# 613743           390.4744                 387.9732              383.3452
#
#         Overall_Literacy  Average_Score
# 4             476.392433          367.3
# 7             299.628400          367.3
# 8             366.084000          367.3
# 15            298.515767          367.3
# 16            353.114533          367.3
# ...                  ...            ...
# 613730        464.452167          351.7
# 613731        318.566800          351.7
# 613733        405.076767          351.7
# 613742        354.658367          351.7
# 613743        387.264267          351.7
#
# [203378 rows x 17 columns]

# %% [markdown]
# Fixing datatype

# %%
df_pisa2022_final['OECD'] = df_pisa2022_final.OECD.astype('category')
df_pisa2022_final['OECD'].dtypes
# Out:
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\3372903856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pisa2022_final['OECD'] = df_pisa2022_final.OECD.astype('category')
# CategoricalDtype(categories=['NON-OECD', 'OECD'], ordered=False, categories_dtype=object)

# %%
df_pisa2022_final['Gender'] = df_pisa2022_final.Gender.astype('category')
df_pisa2022_final['Student_Grade'] = df_pisa2022_final.Student_Grade.astype('float64')
df_pisa2022_final['Perseverance_Give_up_easily'] = df_pisa2022_final.Perseverance_Give_up_easily.astype('category')
df_pisa2022_final['Smartphone_with_internet'] = df_pisa2022_final.Smartphone_with_internet.astype('category')
df_pisa2022_final['Internet_access'] = df_pisa2022_final.Internet_access.astype('category')
df_pisa2022_final['Feel_lonely_at_school'] = df_pisa2022_final.Feel_lonely_at_school.astype('category')
df_pisa2022_final['Study_for_school_or_homework'] = df_pisa2022_final.Study_for_school_or_homework.astype('category')
# Out:
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\425176362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pisa2022_final['Gender'] = df_pisa2022_final.Gender.astype('category')
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\425176362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pisa2022_final['Student_Grade'] = df_pisa2022_final.Student_Grade.astype('float64')
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\425176362.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pisa2022_final['Perseverance_Give_up_easily'] = df_pisa2022_final.Perseverance_Give_up_easily.astype('category')
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\425176362.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pisa2022_final['Smartphone_with_internet'] = df_pisa2022_final.Smartphone_with_internet.astype('category')
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\425176362.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pisa2022_final['Internet_access'] = df_pisa2022_final.Internet_access.astype('category')
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\425176362.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pisa2022_final['Feel_lonely_at_school'] = df_pisa2022_final.Feel_lonely_at_school.astype('category')
# C:\Users\1stApril\AppData\Local\Temp\ipykernel_5348\425176362.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pisa2022_final['Study_for_school_or_homework'] = df_pisa2022_final.Study_for_school_or_homework.astype('category')

# %%
df_pisa2022_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 203378 entries, 4 to 613743
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   School_ID                          203378 non-null  float64
#  1   Student_ID                         203378 non-null  float64
#  2   Country/Region                     203378 non-null  object
#  3   OECD                               203378 non-null  category
#  4   Student_Grade                      203378 non-null  float64
#  5   Gender                             203378 non-null  category
#  6   Smartphone_with_internet           203378 non-null  category
#  7   Internet_access                    203378 non-null  category
#  8   Perseverance_Give_up_easily        203378 non-null  category
#  9   Feel_lonely_at_school              203378 non-null  category
#  10  Study_for_school_or_homework       203378 non-null  category
#  11  Highest_educational_level_parents  203378 non-null  float64
#  12  Avg_Math_Literacy                  203378 non-null  float64
#  13  Avg_Scientific_Literacy            203378 non-null  float64
#  14  Avg_Reading_Literacy               203378 non-null  float64
#  15  Overall_Literacy                   203378 non-null  float64
#  16  Average_Score                      203378 non-null  float64
# dtypes: category(7), float64(9), object(1)
# memory usage: 18.4+ MB

# %%
plt.figure(figsize=(15,16))
sb.countplot(data=df_pisa2022_final, y= 'Country/Region', color='darkblue', order = df_pisa2022_final['Country/Region'].value_counts(ascending=False).index);

# %%
df_pisa2022_final.to_csv('pisa2022.csv', index=False)
