# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline


pd.options.display.max_rows = 9999

# %%
pisa2022_df = pd.read_sas(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\STU_QQQ_SAS\cy08msp_stu_qqq.sas7bdat", encoding='cp1252')
pisa2022_df
# Out:
#         CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen STRATUM SUBNATIO  \
# 0       ALB      8.0    800282.0    800001.0  08MS  000800   ALB03  0080000
# 1       ALB      8.0    800115.0    800002.0  08MS  000800   ALB03  0080000
# 2       ALB      8.0    800242.0    800003.0  08MS  000800   ALB01  0080000
# 3       ALB      8.0    800245.0    800005.0  08MS  000800   ALB08  0080000
# 4       ALB      8.0    800285.0    800006.0  08MS  000800   ALB03  0080000
# ...     ...      ...         ...         ...   ...     ...     ...      ...
# 613739  UZB    860.0  86000120.0  86007488.0  08MS  086000   UZB26  8600000
# 613740  UZB    860.0  86000140.0  86007489.0  08MS  086000   UZB04  8600000
# 613741  UZB    860.0  86000024.0  86007490.0  08MS  086000   UZB10  8600000
# 613742  UZB    860.0  86000174.0  86007491.0  08MS  086000   UZB16  8600000
# 613743  UZB    860.0  86000123.0  86007492.0  08MS  086000   UZB10  8600000
#
# ...

# %%
pisa2022_df.head()
# Out:
#    CNT  CNTRYID  CNTSCHID  CNTSTUID   CYC  NatCen STRATUM SUBNATIO  REGION  \
# 0  ALB      8.0  800282.0  800001.0  08MS  000800   ALB03  0080000   800.0
# 1  ALB      8.0  800115.0  800002.0  08MS  000800   ALB03  0080000   800.0
# 2  ALB      8.0  800242.0  800003.0  08MS  000800   ALB01  0080000   800.0
# 3  ALB      8.0  800245.0  800005.0  08MS  000800   ALB08  0080000   800.0
# 4  ALB      8.0  800285.0  800006.0  08MS  000800   ALB03  0080000   800.0
#
#    OECD  ...  PV4MPRE  PV5MPRE  PV6MPRE  PV7MPRE  PV8MPRE  PV9MPRE  PV10MPRE  \
# 0   0.0  ...  203.029  219.817  331.017  223.752  305.671  230.156   289.436
# 1   0.0  ...  321.405  320.452  284.836  364.565  304.044  347.626   352.269
# 2   0.0  ...  376.019  285.901  289.896  338.469  316.296  324.361   343.351
# 3   0.0  ...  303.422  327.793  165.575  246.156  238.322  275.860   227.466
# 4   0.0  ...  514.739  539.850  461.793  514.465  510.462  490.537   503.793
#
#      SENWT           VER_DAT      i
# ...

# %%
pisa2022_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613744 entries, 0 to 613743
# Data columns (total 1279 columns):
#  #     Column        Dtype
# ---    ------        -----
#  0     CNT           object
#  1     CNTRYID       float64
#  2     CNTSCHID      float64
#  3     CNTSTUID      float64
#  4     CYC           object
#  5     NatCen        object
#  6     STRATUM       object
#  7     SUBNATIO      object
#  8     REGION        float64
#  9     OECD          float64
#  10    ADMINMODE     float64
#  11    LANGTEST_QQQ  float64
#  12    LANGTEST_COG  float64
#  13    LANGTEST_PAQ  float64
#  14    Option_CT     float64
#  15    Option_FL     float64
#  16    Option_ICTQ   float64
#  17    Option_WBQ    float64
#  18    Option_PQ     float64
#  19    Option_TQ     float64
#  20    Option_UH     float64
#  21    BOOKID        float64
#  22    ST001D01T     float64
#  23    ST003D02T     float64
#  24    ST003D03T     float64
#  25    ST004D01T     float64
# ...

# %%
'''columns_to_process = ['Weighted N','Grade 7', 'Grade 8', 'Grade 9', 'Grade 10', 'Grade 11', 'Grade 12', 'Grade 13','Ungraded']

# Loop through each column and handle '—' data
for col in columns_to_process:
    # Replace '—' with NaN (missing value) in the column
    math_stu_grade[col] = math_stu_grade[col].replace('—', pd.NA)
    
    # Convert the column to numeric type
    math_stu_grade[col] = pd.to_numeric(math_stu_grade[col], errors='coerce')
math_stu_grade.describe()'''
# Out:
# "columns_to_process = ['Weighted N','Grade 7', 'Grade 8', 'Grade 9', 'Grade 10', 'Grade 11', 'Grade 12', 'Grade 13','Ungraded']\n\n# Loop through each column and handle '—' data\nfor col in columns_to_process:\n    # Replace '—' with NaN (missing value) in the column\n    math_stu_grade[col] = math_stu_grade[col].replace('—', pd.NA)\n    \n    # Convert the column to numeric type\n    math_stu_grade[col] = pd.to_numeric(math_stu_grade[col], errors='coerce')\nmath_stu_grade.describe()"

# %%
pisa2022_avr_scores_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\Average_score.csv", encoding = "ISO-8859-1")
pisa2022_avr_scores_df
# Out:
#     Rank         Country/Region  Mathemethics_Scores
# 0      1              Singapore                  575
# 1      2          Macao (China)                  552
# 2      3         Chinese Taipei                  547
# 3      4      Hong Kong (China)                  540
# 4      5                  Japan                  536
# 5      6                  Korea                  527
# 6      7                Estonia                  510
# 7      8            Switzerland                  508
# 8      9                 Poland                  498
# 9     10                 Canada                  497
# 10    11            Netherlands                  493
# 11    12                Ireland                  492
# 12    13                Belgium                  489
# 13    14                Denmark                  489
# 14    15         United Kingdom                  489
# 15    16              Australia                  487
# 16    17                Austria                  487
# ...

# %%
pisa2022_math_scores_df = pd.read_csv(r"C:\1stApril\Work\4rd_Year\4rd2\CSS400 Project Development\CN1-2023\PisaTest2022-analysis\csv_file_data\math_score.csv",encoding = "ISO-8859-1")
pisa2022_math_scores_df
# Out:
#     Rank         Country/Region  Mathemethics_Scores
# 0      1              Singapore                  575
# 1      2          Macao (China)                  552
# 2      3         Chinese Taipei                  547
# 3      4      Hong Kong (China)                  540
# 4      5                  Japan                  536
# 5      6                  Korea                  527
# 6      7                Estonia                  510
# 7      8            Switzerland                  508
# 8      9                 Poland                  498
# 9     10                 Canada                  497
# 10    11            Netherlands                  493
# 11    12                Ireland                  492
# 12    13                Belgium                  489
# 13    14                Denmark                  489
# 14    15         United Kingdom                  489
# 15    16              Australia                  487
# 16    17                Austria                  487
# ...
